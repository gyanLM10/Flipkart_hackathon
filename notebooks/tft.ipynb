# %% [markdown]
# # Phase 3: Temporal Fusion Transformer (TFT) Pipeline
# Starting the PyTorch Forecasting pipeline.

# %%
import pandas as pd
import numpy as np

# Load the data with the engineered features
full_df = pd.read_csv('../data/dataset/engineered_full_data.csv')
display(full_df.head())
